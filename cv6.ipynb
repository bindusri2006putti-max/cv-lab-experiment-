# %% [markdown]
# <a href="https://colab.research.google.com/github/bindusri2006putti-max/cv-lab-experiment-/blob/main/cv6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def filteredimage(img, kernel, p, s):
    m = img.shape[0]
    n = img.shape[1]
    km = kernel.shape[0]
    kn = kernel.shape[1]
    rows = int((m - km + 2 * p) / s) + 1
    cols = int((n - kn + 2 * p) / s) + 1
    output = np.ones((rows, cols))
    padding = np.pad(img, p, mode='constant', constant_values=0)
    for i in range(rows):
        for j in range(cols):
            output[i][j] = np.sum(padding[i*s:i*s+km, j*s:j*s+kn] * kernel)
    return output

k = 15
p = 2
s = 2
img = cv2.imread("/content/drive/MyDrive/cv6/images.jpg", 0)
kernel = np.ones((k, k)) / k**2
filtered_output = filteredimage(img, kernel, p, s)
cv2_imshow(filtered_output)
# Out:
# <PIL.Image.Image image mode=L size=203x365>
